# %%
import json
import matplotlib.pyplot as plt
import numpy as np

# %%
with open('history_adam_100.json') as file:
    adam = json.load(file)
with open('history_sgd_100.json') as file:
    sgd = json.load(file)

# %%
N = np.arange(0,len(data["loss"]))
plt.style.use("ggplot")
plt.figure()
axes = plt.gca()
plt.plot(N, adam["loss"], label="train_loss_adam")
plt.plot(N, sgd["loss"], label="train_loss_sgd")
plt.title("Adam and SGD Training Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
axes.set_ylim([0,8000])
plt.legend()
plt.savefig("train")

# %%
N = np.arange(0,len(data["val_loss"]))
plt.style.use("ggplot")
plt.figure()
axes = plt.gca()
plt.plot(N, adam["val_loss"], label="val_loss_adam")
plt.plot(N, sgd["val_loss"], label="val_loss_sgd")
plt.title("Adam and SGD Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Val_Loss")
axes.set_ylim([1000,8000])
plt.legend()
plt.savefig("val")
