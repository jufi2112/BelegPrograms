# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import os

# %%
path = '/media/julien/Transcend/Beleg/predictions'
file_mmae = os.path.join(path, 'sgd_MMAE', '9_summary.jpg')
file_mrmse = os.path.join(path, 'sgd_MRMSE', '9_summary.jpg')

# %%
mmae = cv2.imread(file_mmae, cv2.IMREAD_COLOR)
mrmse = cv2.imread(file_mrmse, cv2.IMREAD_COLOR)

# %%
# %matplotlib inline
plt.imshow(mmae)
plt.show()
plt.imshow(mrmse)
plt.show()

# %%
mmae.shape
# Out:
# (960, 1920, 3)

# %%
# copy upper right two images from mrmse and overwrite lower right two images from mmae
copy_region = mrmse[0:int(mrmse.shape[0]/2),int(mrmse.shape[1]/3):mrmse.shape[1],:]

# %%
# %matplotlib inline
plt.imshow(copy_region)
plt.show()

# %%
# paste
mmae[int(mmae.shape[0]/2):mmae.shape[0],int(mmae.shape[1]/3):mmae.shape[1],:] = copy_region

# %%
# %matplotlib inline
plt.imshow(mmae)
plt.show()

# %%
cv2.imwrite('mmae_vs_mrmse_2.jpg',mmae)
# Out:
# True
